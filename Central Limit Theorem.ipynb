# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns

# %%
track_mean = []
for n in range(1000):
    track_mean.append(np.random.rand(100,1).mean())

# %%
sns.displot(track_mean)

# %%
track_mean = []
for n in range(100000):
    track_mean.append(np.random.rand(100,1).mean())

# %%
sns.displot(track_mean)

# %%
track_mean = []
for n in range(100000):
    track_mean.append(np.random.exponential(scale=1.0,size = 100).mean())

# %%
sns.displot(track_mean)

# %%
data = np.random.normal(loc=5.5, scale=.65, size=100000)

# %%
sns.displot(data)

# %%
len(data[data>6])/len(data)
# Out:
# 0.22142

# %%
len(data[data>6.5])
# Out:
# 6220

# %%
data_sub = data[data>5]

# %%
np.random.choice(data_sub, size = 10)
# Out:
# array([5.05434597, 6.64364503, 5.22218232, 6.65000167, 5.47285553,
#        6.81736069, 5.88268192, 5.86525412, 5.26809535, 5.64692705])

# %%
len(data[data<6])/len(data)*len(data[data<6])/len(data)*len(data[data<6])/len(data)
# Out:
# 0.47196493151271207
