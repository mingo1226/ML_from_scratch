# %% [markdown]
# Simple run through of Kmeans from scratch. Need to make simple improvements including measuring inertia, extend to more than 2 variables, avoid swapping between arrays and dataframes, and create final funciton.

# %%
from sklearn import datasets
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns

# %%
iris = datasets.load_iris()
X = iris.data[:, :2]  # we only take the first two features.
y = iris.target

# %%
figure(figsize=(10, 8), dpi=80)

sns.set_style("darkgrid")
plt.title('Iris Data')
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")
plt.scatter(X[:,0], X[:, 1], c=y, cmap=plt.cm.Set1)
plt.show()

# %%
n_variables = X.shape[1]
max_ = []
min_ = []
for n in range(n_variables):
    max_.append(X[:,n].max())
    min_.append(X[:,n].min())

# %%
centroid
# Out:
# dict_values([5.405290327133573])

# %%
k = 3

centroid = {}

for cluster in range(k):
    coords = []
    for n in range(n_variables):
        coords.append(random.uniform(min_[n], max_[n]))
    centroid[cluster] = coords
    print(centroid)
        #centorid[cluster] = random.uniform(min_[n], max_[n])
        #centorid.update(random.uniform(min_[n], max_[n]))
# Out:
# {0: [7.537235370370016, 2.493073158460505]}
# {0: [7.537235370370016, 2.493073158460505], 1: [4.301297637867926, 2.2647422019515147]}
# {0: [7.537235370370016, 2.493073158460505], 1: [4.301297637867926, 2.2647422019515147], 2: [5.764881350302973, 2.884826806021949]}

# %%
centroid
# Out:
# {0: [7.537235370370016, 2.493073158460505],
#  1: [4.301297637867926, 2.2647422019515147],
#  2: [5.764881350302973, 2.884826806021949]}

# %%
c = pd.DataFrame(centroid)
c.T
# Out:
#           0         1
# 0  7.537235  2.493073
# 1  4.301298  2.264742
# 2  5.764881  2.884827

# %%
import random
k = 3

x_centroid = []
y_centroid = []

for n in range(k):
    x_centroid.append(random.uniform(var1_min, var1_max))
    y_centroid.append(random.uniform(var2_min, var2_max))
    
centroids = list(zip(x_centroid,y_centroid))

# %%
centroids
# Out:
# [(5.724948658954845, 3.1188561481437076),
#  (7.713356554794517, 4.129282575044861),
#  (6.245667297981946, 2.183651651384172)]

# %%
var1_min = X[:,0].min()
var1_max = X[:,0].max()

var2_min = X[:,1].min()
var2_max = X[:,1].max()

# %%
import random
k = 3

x_centroid = []
y_centroid = []

for n in range(k):
    x_centroid.append(random.uniform(var1_min, var1_max))
    y_centroid.append(random.uniform(var2_min, var2_max))
    
centroids = list(zip(x,y))

# %%
c_array = np.column_stack((x_centroid,y_centroid))

# %%
c_array
# Out:
# array([[7.59165776, 2.35935316],
#        [6.40555666, 3.97971427],
#        [5.09320859, 2.67982731]])

# %%
figure(figsize=(10, 8), dpi=80)

sns.set_style("darkgrid")
plt.title('Iris Data')
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")
plt.scatter(X[:,0], X[:, 1], c=y, cmap=plt.cm.Set1)
plt.scatter(c_array[:,0], c_array[:,1])
plt.show()

# %%
import random
k = 3

x_centroid = []
y_centroid = []

#create initial centroids
for n in range(k):
    x_centroid.append(random.uniform(var1_min, var1_max))
    y_centroid.append(random.uniform(var2_min, var2_max))
    
centroids = list(zip(x_centroid,y_centroid))


c_array = np.column_stack((x_centroid,y_centroid))
print(c_array)

cluster = []
for x in X:
    a = np.linalg.norm(x-c_array[0])
    b = np.linalg.norm(x-c_array[1])
    c = np.linalg.norm(x-c_array[2])

    cluster.append(np.array([a,b,c]).argmin())

points_df = pd.DataFrame(X, columns = ['X_1', 'X_2'])
points_df['cluster'] = cluster

updated_points = points_df.groupby('cluster').mean()
updated_points

for n in range(50):
    c_array = np.column_stack((updated_points['X_1'],updated_points['X_2']))
    #assign each point a cluster
    cluster = []
    for x in X:
        a = np.linalg.norm(x-c_array[0])
        b = np.linalg.norm(x-c_array[1])
        c = np.linalg.norm(x-c_array[2])

        cluster.append(np.array([a,b,c]).argmin())
        
    points_df = pd.DataFrame(X, columns = ['X_1', 'X_2'])
    points_df['cluster'] = cluster
    
    updated_points = points_df.groupby('cluster').mean()
updated_points
# Out:
# [[7.44242517 2.0668199 ]
#  [5.55559811 2.95793936]
#  [7.40752836 4.28101306]]
#               X_1       X_2
# cluster
# 0        5.800000  2.700000
# 1        5.003922  3.409804
# 2        6.823913  3.078261

# %%
figure(figsize=(10, 8), dpi=80)

sns.set_style("darkgrid")
plt.title('Iris Data')
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")
plt.scatter(X[:,0], X[:, 1], c=y, cmap=plt.cm.Set1)
plt.scatter(updated_points['X_1'], updated_points['X_2'])
plt.show()

# %%
updated_points
# Out:
#               X_1       X_2
# cluster
# 0        5.800000  2.700000
# 1        5.003922  3.409804
# 2        6.823913  3.078261

# %%
updated_points
# Out:
#               X_1       X_2
# cluster
# 0        5.773585  2.692453
# 1        6.812766  3.074468
# 2        5.006000  3.428000
